# %% [markdown]
# # 01 - EDA Inicial
#
# Notebook preparado para a primeira exploracao da base de vendas de sorvetes.
#
# Status: template criado. Nenhuma analise executada.

# %% [markdown]
# ## Objetivos
#
# - Carregar a base original somente para leitura.
# - Entender estrutura, colunas e tipos de dados.
# - Avaliar qualidade dos dados antes de qualquer tratamento.
# - Registrar hipoteses e proximos passos.

# %%
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
RAW_DATA_PATH = PROJECT_ROOT / "data" / "raw" / "vendas_sorvetes.csv"

RAW_DATA_PATH

# %% [markdown]
# ## Carregamento
#
# Executar apenas quando a etapa de analise exploratoria for iniciada.

# %%
# df = pd.read_csv(RAW_DATA_PATH)
# df.head()

# %% [markdown]
# ## Checklist Da EDA
#
# - Dimensoes da base.
# - Tipos de dados.
# - Valores ausentes.
# - Duplicidades.
# - Consistencia de datas.
# - Consistencia de valores monetarios e quantidades.
# - Colunas candidatas a dimensoes e metricas.
# - Hipoteses de negocio para aprofundamento.
